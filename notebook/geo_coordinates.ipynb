# %%
import pandas as pd

# Load the dataset
file_path = '../data/raw/Air_Quality_20240801.csv'
data = pd.read_csv(file_path)

# Create a dictionary with coordinates for each 'Geo Place Name'
geo_coordinates = {
    'Southeast Queens': (40.6809, -73.7704),
    'Bensonhurst - Bay Ridge': (40.6111, -74.0125),
    'Rockaways': (40.5795, -73.8371),
    'Coney Island - Sheepshead Bay': (40.5884, -73.9559),
    'Williamsburg - Bushwick': (40.7071, -73.9235),
    'Bayside - Little Neck': (40.7644, -73.7494),
    'Pelham - Throgs Neck': (40.8370, -73.8274),
    'Upper West Side': (40.7870, -73.9754),
    'East New York': (40.6695, -73.8822),
    'Canarsie - Flatlands': (40.6400, -73.9101),
    'Jamaica': (40.7027, -73.7889),
    'Gramercy Park - Murray Hill': (40.7365, -73.9824),
    'Hunts Point - Mott Haven': (40.8201, -73.9018),
    'Southwest Queens': (40.6795, -73.8417),
    'Greenwich Village - SoHo': (40.7282, -74.0021),
    'Brooklyn': (40.6782, -73.9442),
    'Downtown - Heights - Slope': (40.6872, -73.9903),
    'Washington Heights': (40.8467, -73.9362),
    'Northeast Bronx': (40.8712, -73.8362),
    'Greenpoint': (40.7245, -73.9419),
    'Long Island City - Astoria': (40.7447, -73.9485),
    'Port Richmond': (40.6335, -74.1387),
    'Kingsbridge - Riverdale': (40.8803, -73.9055),
    'Rockaway and Broad Channel (CD14)': (40.6017, -73.8145),
    'Upper West Side (CD7)': (40.7870, -73.9754),
    'Flushing and Whitestone (CD7)': (40.7675, -73.8207),
    'Bushwick (CD4)': (40.6957, -73.9171),
    'Bedford Stuyvesant (CD3)': (40.6840, -73.9408),
    'Jackson Heights (CD3)': (40.7557, -73.8831),
    'East Flatbush - Flatbush': (40.6537, -73.9306),
    'Elmhurst and Corona (CD4)': (40.7423, -73.8710),
    'Highbridge and Concourse (CD4)': (40.8384, -73.9272),
    'Lower East Side and Chinatown (CD3)': (40.7158, -73.9955),
    'Morrisania and Crotona (CD3)': (40.8403, -73.9029),
    'Upper East Side (CD8)': (40.7736, -73.9566),
    'Central Harlem (CD10)': (40.8116, -73.9465),
    'Washington Heights and Inwood (CD12)': (40.8506, -73.9382),
    'Union Square - Lower East Side': (40.7323, -73.9876),
    'Manhattan': (40.7831, -73.9712),
    'Bedford Stuyvesant - Crown Heights': (40.6758, -73.9415),
    'High Bridge - Morrisania': (40.8275, -73.9220),
    'Woodside and Sunnyside (CD2)': (40.7458, -73.9039),
    'Hunts Point and Longwood (CD2)': (40.8172, -73.8950),
    'Greenwich Village and Soho (CD2)': (40.7282, -74.0021),
    'Upper East Side': (40.7736, -73.9566),
    'Crotona -Tremont': (40.8462, -73.8936),
    'Flushing - Clearview': (40.7675, -73.8207),
    'East Harlem': (40.7957, -73.9389),
    'Fordham - Bronx Pk': (40.8565, -73.8873),
    'Chelsea - Clinton': (40.7465, -74.0014),
    'Central Harlem - Morningside Heights': (40.8116, -73.9465),
    'Fresh Meadows': (40.7335, -73.7801),
    'Bay Ridge and Dyker Heights (CD10)': (40.6176, -74.0288),
    'Fort Greene and Brooklyn Heights (CD2)': (40.6957, -73.9782),
    'Greenpoint and Williamsburg (CD1)': (40.7245, -73.9419),
    'Mott Haven and Melrose (CD1)': (40.8077, -73.9188),
    'Lower Manhattan': (40.7075, -74.0113),
    'West Queens': (40.7423, -73.9070),
    'Parkchester and Soundview (CD9)': (40.8296, -73.8671),
    'Kew Gardens and Woodhaven (CD9)': (40.7045, -73.8301),
    'Morris Park and Bronxdale (CD11)': (40.8540, -73.8605),
    'Bayside and Little Neck (CD11)': (40.7644, -73.7494),
    'Morningside Heights and Hamilton Heights (CD9)': (40.8116, -73.9504),
    'East Harlem (CD11)': (40.7957, -73.9389),
    'South Crown Heights and Lefferts Gardens (CD9)': (40.6635, -73.9515),
    'East New York and Starrett City (CD5)': (40.6643, -73.8826),
    'Midtown (CD5)': (40.7549, -73.9840),
    'Queens': (40.7282, -73.7949),
    'Queens Village (CD13)': (40.7163, -73.7420),
    'Park Slope and Carroll Gardens (CD6)': (40.6761, -73.9816),
    'Stuyvesant Town and Turtle Bay (CD6)': (40.7336, -73.9802),
    'Hillcrest and Fresh Meadows (CD8)': (40.7282, -73.7949),
    'Bronx': (40.8448, -73.8648),
    'Long Island City and Astoria (CD1)': (40.7447, -73.9485),
    'Fordham and University Heights (CD5)': (40.8615, -73.9002),
    'Riverdale and Fieldston (CD8)': (40.8803, -73.9055),
    'Clinton and Chelsea (CD4)': (40.7465, -74.0014),
    'Crown Heights and Prospect Heights (CD8)': (40.6745, -73.9404),
    'Rego Park and Forest Hills (CD6)': (40.7256, -73.8602),
    'Bensonhurst (CD11)': (40.6019, -73.9940),
    'Sunset Park': (40.6455, -74.0129),
    'Brownsville (CD16)': (40.6587, -73.9199),
    'St. George and Stapleton (CD1)': (40.6437, -74.0735),
    'Financial District (CD1)': (40.7075, -74.0113),
    'Borough Park': (40.6334, -73.9952),
    'Coney Island (CD13)': (40.5755, -73.9800),
    'Sheepshead Bay (CD15)': (40.5865, -73.9506),
    'Staten Island': (40.5795, -74.1502),
    'Ridgewood - Forest Hills': (40.7092, -73.8531),
    'Belmont and East Tremont (CD6)': (40.8499, -73.8884),
    'Flatbush and Midwood (CD14)': (40.6408, -73.9590),
    'Borough Park (CD12)': (40.6334, -73.9952),
    'East Flatbush (CD17)': (40.6537, -73.9306),
    'Ridgewood and Maspeth (CD5)': (40.7128, -73.8895),
    'Willowbrook': (40.6011, -74.1366),
        'Throgs Neck and Co-op City (CD10)': (40.8210, -73.8270),
    'Williamsbridge and Baychester (CD12)': (40.8770, -73.8450),
    'Jamaica and Hollis (CD12)': (40.7070, -73.7920),
    'South Ozone Park and Howard Beach (CD10)': (40.6640, -73.8420),
    'Kingsbridge Heights and Bedford (CD7)': (40.8680, -73.8920),
    'Sunset Park (CD7)': (40.6450, -74.0100),
    'Northern SI': (40.6276, -74.1446),
    'Stapleton - St. George': (40.6415, -74.0787),
    'Southern SI': (40.5493, -74.1502),
    'Flatlands and Canarsie (CD18)': (40.6213, -73.9143),
    'South Beach and Willowbrook (CD2)': (40.5896, -74.0760),
    'Bayside Little Neck-Fresh Meadows': (40.7498, -73.7808),
    'South Beach - Tottenville': (40.5232, -74.2065),
    'South Bronx': (40.8154, -73.8978),
    'Tottenville and Great Kills (CD3)': (40.5125, -74.2516),
    'Upper East Side-Gramercy': (40.7371, -73.9815),
    'Chelsea-Village': (40.7429, -74.0030),
    'Union Square-Lower Manhattan': (40.7359, -73.9911),
    'New York City': (40.7128, -74.0060)
}

# Create separate columns for latitude and longitude
data['Latitude'] = data['Geo Place Name'].map(lambda x: geo_coordinates.get(x, (None, None))[0])
data['Longitude'] = data['Geo Place Name'].map(lambda x: geo_coordinates.get(x, (None, None))[1])

# Save the updated dataframe to a new CSV file
data.to_csv('../data/processed/Air_Quality_with_Coordinates.csv', index=False)

# Display the dataframe to verify the changes
print(data.head())
# Out:
#    Unique ID  Indicator ID                                   Name  \
# 0     179772           640  Boiler Emissions- Total SO2 Emissions
# 1     179785           640  Boiler Emissions- Total SO2 Emissions
# 2     178540           365                Fine particles (PM 2.5)
# 3     178561           365                Fine particles (PM 2.5)
# 4     823217           365                Fine particles (PM 2.5)
#
#           Measure Measure Info Geo Type Name  Geo Join ID  \
# 0  Number per km2       number         UHF42        409.0
# 1  Number per km2       number         UHF42        209.0
# 2            Mean       mcg/m3         UHF42        209.0
# 3            Mean       mcg/m3         UHF42        409.0
# 4            Mean       mcg/m3         UHF42        409.0
#
#             Geo Place Name          Time Period Start_Date  Data Value  \
# 0         Southeast Queens                 2015   1/1/2015         0.3
# 1  Bensonhurst - Bay Ridge                 2015   1/1/2015         1.2
# ...

# %%
import pandas as pd

# Load the dataset
file2_path ='../data/processed/Air_Quality_with_Coordinates.csv'
data2 = pd.read_csv(file2_path)

# Filter rows where Latitude or Longitude is missing
missing_coords = data2[(data2['Latitude'].isnull()) | (data2['Longitude'].isnull())]

# Get unique Geo Place Name values for missing coordinates
unique_missing_places = missing_coords['Geo Place Name'].unique()

# Print the unique Geo Place Name values
print("Geo Place Names with missing coordinates:")
for place in unique_missing_places:
    print(place)
# Out:
# Geo Place Names with missing coordinates:
# nan
